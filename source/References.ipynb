# %% [markdown]
# <h1 style="text-align: center;">
#     <span style="font-size: 40px; font-weight: bold">
#         CSC17104 – PROGRAMING FOR DATA SCIENCE
#     </span>
# </h1>
#
# <h2 style="text-align: center;">
#     <span style="font-size: 32px; font-weight: bold">
#         FINAL PROJECT
#     </span>
# </h2>
#
# <h3 style="text-align: center;">
#     <span style="font-size: 24px; font-weight: bold">
#         <i>
#             References
#         </i>
#     </span>
# </h3>
#
# <div style="text-align: right;">
#     <span style="font-size: 14px">
#         <i>
#             Dec 16, 2025
#         </i>
#     </span>
# </div>
#
# | Name | ID |
# | --- | --- |
# | Lê Võ Nhật Minh | 22120210 |
# | Nguyễn Hữu Nghĩa | 22120227 |
# | Nguyễn Lê Tấn Phát | 22120262 |

# %% [markdown]
# ---

# %% [markdown]
# [1] Pandas Development Team. (2020). pandas-dev/pandas: Pandas. Zenodo. (https://pandas.pydata.org/docs/)
#
# [2] Waskom, M. L. (2021). seaborn: statistical data visualization. Journal of Open Source Software, 6(60), 3021. (https://seaborn.pydata.org/tutorial.html)
#
# [3] Virtanen, P., et al. (2020). SciPy 1.0: Fundamental Algorithms for Scientific Computing in Python. Nature Methods, 17, 261–272. (https://docs.scipy.org/doc/scipy/)
#
# [4] Frank, E., & Hall, M. (2001). A simple approach to ordinal classification. In Proceedings of the 12th European Conference on Machine Learning (ECML) (Lecture Notes in Computer Science, Vol. 2167, pp. 145–156). Springer. (https://www.researchgate.net/publication/226877154_A_Simple_Approach_to_Ordinal_Classification)
